# %%
import torch
import sys
import folium
import matplotlib.pyplot as plt
sys.path.append('../')

from models.model_utils import AttrDict, load_rid_freqs, get_rid_rnfea_dict, load_rn_dict, toseq
from models.models_attn_tandem import Encoder, DecoderMulti, Seq2SeqMulti
from models.multi_train import evaluate, init_weights, train
from common.mbr import MBR
from common.road_network import load_rn_shp
from models.datasets import Dataset, collate_fn

# %%
def plot_attention(attention, input_seq, output_seq):
    """
    Plots a heatmap of attention weights.
    
    :param attention: A 2D numpy array of attention weights.
    :param input_seq: List of input tokens.
    :param output_seq: List of output tokens.
    """
    fig, ax = plt.subplots()
    cax = ax.matshow(attention, cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_seq, rotation=90)
    ax.set_yticklabels([''] + output_seq)

    # Show label at every tick
    ax.xaxis.set_major_locator(plt.MultipleLocator(1))
    ax.yaxis.set_major_locator(plt.MultipleLocator(1))

    plt.show()

# %%
args = AttrDict()
device = torch.device('cuda')
args_dict = {'module_type': 'simple', 'debug': False, 'device': device, 'load_pretrained_flag': False, 'model_old_path': '', 'train_flag': True, 'test_flag': False, 'attn_flag': True, 'dis_prob_mask_flag': False, 'search_dist': 50, 'beta': 15, 'tandem_fea_flag': False, 'pro_features_flag': False, 'online_features_flag': False, 'rid_fea_dim': 8, 'pro_input_dim': 30, 'pro_output_dim': 8, 'poi_num': 5, 'online_dim': 10, 'poi_type': 'company,food,shopping,viewpoint,house', 'min_lat': 41.146, 'min_lng': -8.62, 'max_lat': 41.148, 'max_lng': -8.618, 'keep_ratio': 0.125, 'grid_size': 50, 'time_span': 15, 'win_size': 25, 'ds_type': 'random', 'split_flag': False, 'shuffle': True, 'hid_dim': 512, 'id_emb_dim': 128, 'dropout': 0.1, 'id_size': 30, 'lambda1': 10, 'n_epochs': 10, 'batch_size': 128, 'learning_rate': 0.001, 'tf_ratio': 0.5, 'clip': 1, 'log_step': 1, 'nhead': 8, 'nlayers': 2, 'max_xid': 5, 'max_yid': 4}
args.update(args_dict)

# %%
enc = Encoder(args)
dec = DecoderMulti(args)
model = TransformerModel(enc, dec, args).to(device)
model.apply(init_weights)
# Out:
# TransformerModel(
#   (pos_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer_encoder): CustomTransformerEncoder(
#     (layers): ModuleList(
#       (0): CustomEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): ReLU()
#       )
#       (1): CustomEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): ReLU()
#       )
#     )
#   )
#   (transformer_decoder): CustomTransformerDecoder(
#     (layers): ModuleList(
#       (0): CustomDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#         (activation): ReLU()
#       )
#       (1): CustomDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#         (activation): ReLU()
#       )
#     )
#   )
#   (encoder_id): Embedding(30, 512)
#   (encoder): Encoder(
#     (rnn): GRU(3, 512)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): DecoderMulti(
#     (emb_id): Embedding(30, 128)
#     (tandem_fc): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU()
#     )
#     (fc_id_out): Linear(in_features=512, out_features=30, bias=True)
#     (fc_rate_out): Linear(in_features=512, out_features=1, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
model_path = '../results/simple_kr_0.125_debug_False_gs_50_lam_10_attn_True_prob_False_fea_False_20240412_192558/'
model.load_state_dict(torch.load(model_path + 'val-best-model.pt'))
# Out:
# <All keys matched successfully>

# %%
test_trajs_dir = "../data/model_data/test_data/"
rn_dir = "../data/map/road_network/"
extra_info_dir = "../data/map/extra_info/"

new2raw_rid_dict = load_rid_freqs(extra_info_dir, file_name='new2raw_rid.json')
rn_dict = load_rn_dict(extra_info_dir, file_name='rn_dict.json')
rid_features_dict = get_rid_rnfea_dict(rn_dict, args)
rn = load_rn_shp(rn_dir, is_directed=True)
mbr = MBR(args.min_lat, args.min_lng, args.max_lat, args.max_lng)
test_dataset = Dataset(
    test_trajs_dir,
    mbr,
    None,
    None,
    None,
    rn,
    new2raw_rid_dict,
    parameters=args,
    is_test=True,
    debug=False
)
# Out:
# # of nodes:31
# # of edges:29
# 100%|███████████████████████████████████████████████████████████████████████████████| 500/500 [00:01<00:00, 258.24it/s]

# %%
print('test dataset shape: ' + str(len(test_dataset)))
test_iterator = torch.utils.data.DataLoader(test_dataset, batch_size=args.batch_size,
    shuffle=args.shuffle, collate_fn=collate_fn,
    num_workers=4, pin_memory=True)
# Out:
# test dataset shape: 8595

# %%
for i, batch in enumerate(test_iterator):
    if i<5:
        continue
    src_grid_seqs, src_gps_seqs, src_pro_feas, src_lengths, trg_gps_seqs, trg_rids, trg_rates, trg_lengths = batch
    src_pro_feas = src_pro_feas.float().to(device)
    max_trg_len = max(trg_lengths)
    batch_size = src_grid_seqs.size(0)
    constraint_mat = torch.zeros(max_trg_len, batch_size, args.id_size).to(device)
    pre_grids = torch.zeros(max_trg_len, batch_size, 3).to(device)
    next_grids = torch.zeros(max_trg_len, batch_size, 3).to(device)
    src_grid_seqs = src_grid_seqs.permute(1, 0, 2).to(device)
    trg_gps_seqs = trg_gps_seqs.permute(1, 0, 2).to(device)
    trg_rids = trg_rids.permute(1, 0, 2).long().to(device)
    trg_rates = trg_rates.permute(1, 0, 2).to(device)
    break

# %%
output_ids, output_rates, attention_weights = model(src_grid_seqs, src_lengths, trg_rids, trg_rates, trg_lengths,
     pre_grids, next_grids, constraint_mat,
     src_pro_feas, None, rid_features_dict,
     teacher_forcing_ratio=0)

output_rates = output_rates.squeeze(2)
output_seqs = toseq(rn_dict, output_ids, output_rates, args)
output_seqs = output_seqs.permute(1,0,2)
trg_gps_seqs = trg_gps_seqs.permute(1,0,2)

# %%
gt = trg_gps_seqs[:,1:]
pred = output_seqs[:,1:]
ls = src_gps_seqs[:,1:]

# %%
traj_index = 66
m = folium.Map(location=gt[traj_index][0], zoom_start=12)
for point in gt[traj_index].tolist():
    folium.Marker(point).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_084e777925352f75dceca1c06863b553 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_084e777925352f75dceca1c06863b553&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_084e777925352f75dceca1c06863b553 = L.map(
#                 &quot;map_084e777925352f75dceca1c06863b553&quot;,
#                 {
#                     center: [41.14584732055664, -8.610831260681152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9240f1945f8bdb2e30a84f259a3f2b5c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_edd7bb8545187fd59a546159ad1817bf = L.marker(
#                 [41.14584732055664, -8.610831260681152],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_2fb48c6283d1cc74b81355aa29b00a86 = L.marker(
#                 [41.14601135253906, -8.610725402832031],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_89b662e72eed62de554274c90eb364b8 = L.marker(
#                 [41.146018981933594, -8.610716819763184],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_18977fe6ff6d00f8feb4b24d44eaaeba = L.marker(
#                 [41.14625930786133, -8.610289573669434],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_e25a09bf209b53179df36cf3508763fb = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_16cf6198d63d79df8e77ed35130246f7 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_c40e894f02ad9c7aa968fbcdf360961c = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_f989ce79c62a21a80423def390db9654 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_29067ea65c86e64dde9c5d66dccb3443 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_ee73abf6933b2f2a7faa5eceef23b483 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_fb573ba90a6a83c40c55d004fdcb7ff7 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_9925697b7406cad69327eb1c9a19df16 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_63774f6ad763176fab8e2768df9718ee = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_a823347dc6983cf52aa47baf837064c2 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_0736314a6f31f7ead703c78caef10c8f = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_16b66ed991b7efb2a59b39103432e3a8 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_009a7034e408d2f9348fa277b5200d4f = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_308797112f10b61de339e65b306d069c = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_52d4542affa510c179b3e5969de9d1d7 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_23fbcbfd151b0efadedccd9e3f8e2076 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_6cdb85cf79f5a644a13757206354db64 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_084e777925352f75dceca1c06863b553);
#
#
#             var marker_663161753fd2827eff8e2e9b0c562a12 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_0

# %%
m = folium.Map(location=pred[traj_index][0], zoom_start=12)
for point in pred[traj_index].tolist():
    folium.Marker(point).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2264a114878651ac9e6dc38d426b6f83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2264a114878651ac9e6dc38d426b6f83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2264a114878651ac9e6dc38d426b6f83 = L.map(
#                 &quot;map_2264a114878651ac9e6dc38d426b6f83&quot;,
#                 {
#                     center: [41.146270751953125, -8.61126708984375],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc89d2f6e979b4a01905ba8a90c1cdc2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_fddf4f6acec35b0e2ff7fea528bf4814 = L.marker(
#                 [41.146270751953125, -8.61126708984375],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_2e2bf32b6c122db2f354b49bb4ee67e0 = L.marker(
#                 [41.14605712890625, -8.61131763458252],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_cf8c16dd8a24a5835b2a0b2f23b7f589 = L.marker(
#                 [41.145851135253906, -8.610830307006836],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_fd9a419004599c49395070b3fc970b09 = L.marker(
#                 [41.14591979980469, -8.610784530639648],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_01994be91301c7b17e1d15c0d805e3db = L.marker(
#                 [41.14596939086914, -8.610760688781738],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_cee8ed24d678ccff6a78ae09663ff80c = L.marker(
#                 [41.14601135253906, -8.610725402832031],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_5c476f2ad180e3758a32467ca87f2297 = L.marker(
#                 [41.146018981933594, -8.610716819763184],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_ea5ee172356740582dc676150f4b09a6 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_7e3baf9880f8162c6614ad6f2216bb00 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_ba46ac4367bb074f5485061880660aac = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_382b66698546308ade198b7296b5c9e1 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_8abb80aabeb3a184f5c728858a7a0f96 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_fb39378aba1ca1747725bde7502ebc05 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_4fec9bfb1d05efb2c836a42cf5ff4de0 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_9a6e34beeb26d16406ecf3222e79c036 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_7b2e2a6ea0a4b80b229c4cc0c6c313e9 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_64416d6f10671d0523af057f0267572e = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_103f41b4b9d540e8e0685b973e6f7dc7 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_7a2d15a22334dde357d1d42cf1f5a65d = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_b23b33f123f13231270535afed181965 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_fc38d33a7b870b8dc6523b4231bd0fe4 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_2264a114878651ac9e6dc38d426b6f83);
#
#
#             var marker_14a0f3c9413a5464d04245ad0e8ca6

# %%
m = folium.Map(location=ls[traj_index][0], zoom_start=12)
for point in ls[traj_index].tolist():
    folium.Marker(point).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_806d63f28116562362008934ca8d94a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_806d63f28116562362008934ca8d94a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_806d63f28116562362008934ca8d94a4 = L.map(
#                 &quot;map_806d63f28116562362008934ca8d94a4&quot;,
#                 {
#                     center: [41.146018981933594, -8.61138916015625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79da1f9aeb125c13f0b0a4d74edb94fb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_806d63f28116562362008934ca8d94a4);
#
#
#             var marker_9a9ff60feacae67112318b0c62919a62 = L.marker(
#                 [41.146018981933594, -8.61138916015625],
#                 {}
#             ).addTo(map_806d63f28116562362008934ca8d94a4);
#
#
#             var marker_5726aff7a34add4435259e8001e070c8 = L.marker(
#                 [41.14558792114258, -8.610795021057129],
#                 {}
#             ).addTo(map_806d63f28116562362008934ca8d94a4);
#
#
#             var marker_eee1b8715d90180b45584b3384f8aa48 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_806d63f28116562362008934ca8d94a4);
#
#
#             var marker_895353ef037c57e1b45873e1c9f38fd1 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_806d63f28116562362008934ca8d94a4);
#
#
#             var marker_58951fd74b04fc2c270de9b3e491ab7b = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_806d63f28116562362008934ca8d94a4);
#
#
#             var marker_8fac84f0fbb1f8d36c2bfa4579f4490b = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_806d63f28116562362008934ca8d94a4);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
attention_weights[0][0].shape
# Out:
# torch.Size([128, 7, 7])

# %%
plot_attention(attention_weights[2][-1][traj_index].cpu().detach().numpy(), list(range(max(src_lengths))), list(range(max(trg_lengths))))
# Out:
# D:\Users\user\anaconda3\envs\OSM\lib\site-packages\ipykernel_launcher.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# D:\Users\user\anaconda3\envs\OSM\lib\site-packages\ipykernel_launcher.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   from ipykernel import kernelapp as app

# %%
ls.
# Out:
# torch.Size([128, 6, 2])
